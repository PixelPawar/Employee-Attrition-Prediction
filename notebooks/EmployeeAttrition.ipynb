# %%
import numpy as nb 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler


sns.set_style('whitegrid')

pd.set_option('display.max_columns',None)

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("../data/raw/data.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='str')

# %%
df = df.drop(columns=["EmployeeNumber"])

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   str
#  2   BusinessTravel            1470 non-null   str
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   str
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   str
#  8   EmployeeCount             1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   str
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
df.select_dtypes(include='object').columns.tolist()
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# ...

# %%
df.describe(include='object')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique().sort_values()
# Out:
# EmployeeCount                  1
# Over18                         1
# StandardHours                  1
# Attrition                      2
# OverTime                       2
# PerformanceRating              2
# Gender                         2
# BusinessTravel                 3
# Department                     3
# MaritalStatus                  3
# WorkLifeBalance                4
# RelationshipSatisfaction       4
# StockOptionLevel               4
# EnvironmentSatisfaction        4
# JobInvolvement                 4
# JobSatisfaction                4
# JobLevel                       5
# Education                      5
# EducationField                 6
# TrainingTimesLastYear          7
# JobRole                        9
# NumCompaniesWorked            10
# PercentSalaryHike             15
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# YearsInCurrentRole            19
# DistanceFromHome              29
# YearsAtCompany                37
# ...

# %%
constant_columns = [
    col for col in df.columns
    if df[col].nunique() == 1
]
constant_columns
# Out:
# ['EmployeeCount', 'Over18', 'StandardHours']

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
(df["Attrition"].value_counts(normalize=True) * 100).round(2)
# Out:
# Attrition
# No     83.88
# Yes    16.12
# Name: proportion, dtype: float64

# %%
# sns.countplot(data=df,x=df.Attrition)

# %%
continuous_columns = df.select_dtypes(include=['int64','float64']).columns.to_list()
categorical_columns = df.select_dtypes(include=['object','str']).columns.to_list()

print("Numerical Columns:")
print(continuous_columns)

print("\nCategorical Columns:")
print(categorical_columns)
# Out:
# Numerical Columns:
# ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
#
# Categorical Columns:
# ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']

# %%
df[continuous_columns].describe().T
# Out:
#                            count          mean          std     min     25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.0
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.0
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.0
# Education                 1470.0      2.912925     1.024165     1.0     2.0
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.0
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.0
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.0
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.0
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.0
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.0
# MonthlyIncome             1470.0   6502.931293  4707.956783  1009.0  2911.0
# ...

# %%
# df[continuous_columns].hist(
#     figsize=(18,15),
#     bins=20
# )
# plt.tight_layout()
# plt.show()

# %%
# plt.figure(figsize=(18,15))

# for i, col in enumerate(continuous_columns, 1):
#     plt.subplot(5, 6, i)
#     sns.boxplot(y=df[col])
#     plt.title(col)

# plt.tight_layout()
# plt.show()

# %%
# plt.figure(figsize=(18,20))

# for i, col in enumerate(categorical_columns, 1):
#     plt.subplot(3, 3, i)
#     sns.countplot(data=df, x=col)
#     plt.xticks(rotation=45)
#     plt.title(col)

# plt.tight_layout()
# plt.show()

# %%
# plt.figure(figsize=(6,4))

# sns.countplot(
#     data=df,
#     x="OverTime",
#     hue="Attrition",
#     palette="Set2"
# )

# plt.title("Attrition by Overtime")
# plt.xlabel("OverTime")
# plt.ylabel("Number of Employees")

# plt.show()

# %%
pd.crosstab(df["OverTime"], df["Attrition"])
# Out:
# Attrition   No  Yes
# OverTime
# No         944  110
# Yes        289  127

# %%
pd.crosstab(
    df["OverTime"],
    df["Attrition"],
    normalize="index"
) * 100
# Out:
# Attrition         No        Yes
# OverTime
# No         89.563567  10.436433
# Yes        69.471154  30.528846

# %%
categorical_columns
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %%
# plt.figure(figsize=(6,4))

# sns.countplot(
#     data=df,
#     x="JobSatisfaction",
#     hue="Attrition",
#     palette="Set2"
# )

# plt.title("Attrition by Overtime")
# plt.xlabel("JobSatisfaction")
# plt.ylabel("Number of Employees")

# plt.show()

# %%
# plt.figure(figsize=(8,5))

# sns.boxplot(
#     data=df,
#     x="Attrition",
#     y="MonthlyIncome",
#     palette="Set2"
# )

# plt.title("Monthly Income vs Attrition")
# plt.xlabel("Attrition")
# plt.ylabel("Monthly Income")

# plt.show()

# %%
df_corr = df.drop(columns=["EmployeeCount", "Over18", "StandardHours"])

# %%
df_corr.Attrition = df.Attrition.map({
    "Yes" : 0,
    "No" : 1,

})

# %%
# plt.figure(figsize=(16,24))

# sns.heatmap(
#     df_corr.corr(numeric_only=True),
#     cmap="coolwarm",
#     annot=False
# )

# plt.title("Correlation Heatmap")
# plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
# # 1. Department vs Attrition
# plt.figure(figsize=(8,5))

# sns.countplot(
#     data=df,
#     x="Department",
#     hue="Attrition",
#     palette="Set2"
# )

# plt.title("Department vs Attrition")
# plt.xticks(rotation=15)
# plt.show()

# %%
department_attrition = pd.crosstab(
    df["Department"],
    df["Attrition"],
    normalize="index"
) * 100

department_attrition
# Out:
# Attrition                      No        Yes
# Department
# Human Resources         80.952381  19.047619
# Research & Development  86.160250  13.839750
# Sales                   79.372197  20.627803

# %%
# 2. Job Role vs Attrition
jobrole_attrition = pd.crosstab(
    df["JobRole"],
    df["Attrition"],
    normalize="index"
) * 100

jobrole_attrition
# Out:
# Attrition                         No        Yes
# JobRole
# Healthcare Representative  93.129771   6.870229
# Human Resources            76.923077  23.076923
# Laboratory Technician      76.061776  23.938224
# Manager                    95.098039   4.901961
# Manufacturing Director     93.103448   6.896552
# Research Director          97.500000   2.500000
# Research Scientist         83.904110  16.095890
# Sales Executive            82.515337  17.484663
# Sales Representative       60.240964  39.759036

# %%
# # 3. Business Travel vs Attrition
# plt.figure(figsize=(7,5))

# sns.countplot(
#     data=df,
#     x="BusinessTravel",
#     hue="Attrition",
#     palette="Set2"
# )

# plt.title("Business Travel vs Attrition")

# plt.show()

# %%
travel_attrition = pd.crosstab(
    df["BusinessTravel"],
    df["Attrition"],
    normalize="index"
) * 100

travel_attrition
# Out:
# Attrition                 No        Yes
# BusinessTravel
# Non-Travel         92.000000   8.000000
# Travel_Frequently  75.090253  24.909747
# Travel_Rarely      85.043145  14.956855

# %%
# # 4. Marital Status vs Attrition
# plt.figure(figsize=(7,5))

# sns.countplot(
#     data=df,
#     x="MaritalStatus",
#     hue="Attrition",
#     palette="Set2"
# )

# plt.title("Marital Status vs Attrition")

# plt.show()

# %%
marital_attrition = pd.crosstab(
    df["MaritalStatus"],
    df["Attrition"],
    normalize="index"
) * 100

marital_attrition
# Out:
# Attrition             No        Yes
# MaritalStatus
# Divorced       89.908257  10.091743
# Married        87.518574  12.481426
# Single         74.468085  25.531915

# %%
# department_attrition.plot(
#     kind="bar",
#     stacked=True,
#     figsize=(8,5)
# )

# plt.ylabel("Percentage")
# plt.title("Department-wise Attrition Percentage")

# plt.show()

# %%
def analyze_numerical_feature(feature):
    print(f"\n{feature}")
    print("-" * 40)

    print(df.groupby("Attrition")[feature].describe())

    plt.figure(figsize=(7,4))
    sns.boxplot(data=df, x="Attrition", y=feature ,palette="Set2")
    plt.show()

# %%
# analyze_numerical_feature("Age")
# analyze_numerical_feature("MonthlyIncome")
# analyze_numerical_feature("DistanceFromHome")
# analyze_numerical_feature("YearsSinceLastPromotion")

# %% [markdown]
# ## Data Preprocessing

# %%
df = df.drop(columns=constant_columns)

# %%
X = df.drop("Attrition" , axis=1)
y = df.Attrition

# %%
print(X.shape)
print(y.shape)
# Out:
# (1470, 30)
# (1470,)

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,random_state=42 , test_size=0.2,stratify=y)

# %%
print(X_train.shape)
print(X_test.shape)

print(y_train.value_counts(normalize=True))
print(y_test.value_counts(normalize=True))
# Out:
# (1176, 30)
# (294, 30)
# Attrition
# No     0.838435
# Yes    0.161565
# Name: proportion, dtype: float64
# Attrition
# No     0.840136
# Yes    0.159864
# Name: proportion, dtype: float64

# %% [markdown]
# ### Feature Encoding

# %%
categorical_columns,continuous_columns
# Out:
# (['Attrition',
#   'BusinessTravel',
#   'Department',
#   'EducationField',
#   'Gender',
#   'JobRole',
#   'MaritalStatus',
#   'Over18',
#   'OverTime'],
#  ['Age',
#   'DailyRate',
#   'DistanceFromHome',
#   'Education',
#   'EmployeeCount',
#   'EnvironmentSatisfaction',
#   'HourlyRate',
#   'JobInvolvement',
#   'JobLevel',
#   'JobSatisfaction',
#   'MonthlyIncome',
#   'MonthlyRate',
#   'NumCompaniesWorked',
#   'PercentSalaryHike',
#   'PerformanceRating',
#   'RelationshipSatisfaction',
#   'StandardHours',
#   'StockOptionLevel',
#   'TotalWorkingYears',
#   'TrainingTimesLastYear',
#   'WorkLifeBalance',
#   'YearsAtCompany',
#   'YearsInCurrentRole',
#   'YearsSinceLastPromotion',
#   'YearsWithCurrManager'])

# %%
categorical_features = X_train.select_dtypes(include="object").columns.tolist()

numerical_features = X_train.select_dtypes(exclude="object").columns.tolist()

# %%
y_train = y_train.map({
    "No":0,
    "Yes":1
})
y_test = y_test.map({
    "No":0,
    "Yes":1
})

# %%
from sklearn.compose import ColumnTransformer

# %%
preprocessor = ColumnTransformer(
    transformers = [
        ("number", StandardScaler() , numerical_features ),
        ("category", OneHotEncoder(handle_unknown="ignore") , categorical_features )
    ]
)

# %%
X_train.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='str')

# %%
X_train_preprocessor = preprocessor.fit_transform(X_train)
X_test_preprocessor = preprocessor.transform(X_test)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# %%
pipeline = Pipeline(
    steps=[
        ("preprocessor" , preprocessor),
        ("classifier" , LogisticRegression(random_state=42))
    ]
)

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('number', StandardScaler(),
#                                                   ['Age', 'DailyRate',
#                                                    'DistanceFromHome',
#                                                    'Education',
#                                                    'EnvironmentSatisfaction',
#                                                    'HourlyRate',
#                                                    'JobInvolvement', 'JobLevel',
#                                                    'JobSatisfaction',
#                                                    'MonthlyIncome',
#                                                    'MonthlyRate',
#                                                    'NumCompaniesWorked',
#                                                    'PercentSalaryHike',
#                                                    'PerformanceRating',
# ...

# %%
y_pred = pipeline.predict(X_test)

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report
)

# %%
print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 0.8605442176870748
# Precision: 0.6153846153846154
# Recall   : 0.3404255319148936
# F1 Score : 0.4383561643835616

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92       247
#            1       0.62      0.34      0.44        47
#
#     accuracy                           0.86       294
#    macro avg       0.75      0.65      0.68       294
# weighted avg       0.84      0.86      0.84       294

# %%
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

plt.show()

# %% [markdown]
# ## Handling Imbalanced Data (SMOTE)

# %%
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression

smote_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("classifier", LogisticRegression(random_state=42))
    ]
)

# %%
smote_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('number', StandardScaler(),
#                                                   ['Age', 'DailyRate',
#                                                    'DistanceFromHome',
#                                                    'Education',
#                                                    'EnvironmentSatisfaction',
#                                                    'HourlyRate',
#                                                    'JobInvolvement', 'JobLevel',
#                                                    'JobSatisfaction',
#                                                    'MonthlyIncome',
#                                                    'MonthlyRate',
#                                                    'NumCompaniesWorked',
#                                                    'PercentSalaryHike',
#                                                    'PerformanceRating',
# ...

# %%
y_pred_smote = smote_pipeline.predict(X_test)

# %%
print(classification_report(y_test, y_pred_smote))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.80      0.85       247
#            1       0.36      0.57      0.44        47
#
#     accuracy                           0.77       294
#    macro avg       0.63      0.69      0.65       294
# weighted avg       0.82      0.77      0.79       294

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("classifier", RandomForestClassifier(
            random_state=42,
            n_estimators=100,
            class_weight="balanced"
        ))
    ]
)

# %%
rf_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('number', StandardScaler(),
#                                                   ['Age', 'DailyRate',
#                                                    'DistanceFromHome',
#                                                    'Education',
#                                                    'EnvironmentSatisfaction',
#                                                    'HourlyRate',
#                                                    'JobInvolvement', 'JobLevel',
#                                                    'JobSatisfaction',
#                                                    'MonthlyIncome',
#                                                    'MonthlyRate',
#                                                    'NumCompaniesWorked',
#                                                    'PercentSalaryHike',
#                                                    'PerformanceRating',
# ...

# %%
y_pred_rf = rf_pipeline.predict(X_test)

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91       247
#            1       0.49      0.36      0.41        47
#
#     accuracy                           0.84       294
#    macro avg       0.68      0.64      0.66       294
# weighted avg       0.82      0.84      0.83       294

# %%
rf_model = rf_pipeline.named_steps["classifier"]

# %%
feature_names = rf_pipeline.named_steps[
    "preprocessor"
].get_feature_names_out()

# %%
importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Importance": rf_model.feature_importances_
})

importance_df = importance_df.sort_values(
    by="Importance",
    ascending=False
)

importance_df.head(15)
# Out:
#                          Feature  Importance
# 9          number__MonthlyIncome    0.074588
# 16     number__TotalWorkingYears    0.058100
# 0                    number__Age    0.055989
# 1              number__DailyRate    0.051154
# 19        number__YearsAtCompany    0.045799
# 2       number__DistanceFromHome    0.043844
# 5             number__HourlyRate    0.040900
# 10           number__MonthlyRate    0.039198
# 11    number__NumCompaniesWorked    0.037727
# 22  number__YearsWithCurrManager    0.035233
# 50        category__OverTime_Yes    0.033341
# 20    number__YearsInCurrentRole    0.030376
# 15      number__StockOptionLevel    0.030258
# 12     number__PercentSalaryHike    0.028871
# 49         category__OverTime_No    0.028174

# %%
top15 = importance_df.head(15)

plt.figure(figsize=(10,6))

plt.barh(top15["Feature"], top15["Importance"])

plt.gca().invert_yaxis()

plt.title("Top 15 Important Features")

plt.xlabel("Importance")

plt.savefig(
    "../images/feature_importance.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Explainable AI (SHAP)

# %%
import shap

# %%
X_train_processed = rf_pipeline.named_steps[
    "preprocessor"
].transform(X_train)

# %%
explainer = shap.TreeExplainer(rf_model)

# %%
shap_values = explainer.shap_values(X_train_processed)

# %%
feature_names = rf_pipeline.named_steps[
    "preprocessor"
].get_feature_names_out()

shap.summary_plot(
    shap_values[:, :, 1],
    X_train_processed,
    feature_names=feature_names,
    show=False
)
plt.savefig(
    "../images/shap.png",
    dpi=300,
    bbox_inches="tight"
)

plt.close()

# %%
employee_index = 10
shap_values = explainer.shap_values(X_train_processed)

shap.waterfall_plot(
    shap.Explanation(
        values=shap_values[1][employee_index],
        base_values=explainer.expected_value[1],
        data=X_train_processed[employee_index],
        feature_names=feature_names,
        
    )
    
)

# %% [markdown]
# ## Hyperparameter tunning

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
param_dist = {
    "classifier__n_estimators": [100, 200, 300, 500],

    "classifier__max_depth": [None, 5, 10, 20, 30],

    "classifier__min_samples_split": [2, 5, 10],

    "classifier__min_samples_leaf": [1, 2, 4],

    "classifier__max_features": ["sqrt", "log2"],

    "classifier__class_weight": [None, "balanced"]
}

# %%
random_search = RandomizedSearchCV(
    estimator=rf_pipeline,
    param_distributions=param_dist,

    n_iter=20,

    scoring="recall",

    cv=5,

    random_state=42,

    n_jobs=-1 #uses all CPU core 
)

# %%
random_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('number',
#                                                                                StandardScaler(),
#                                                                                ['Age',
#                                                                                 'DailyRate',
#                                                                                 'DistanceFromHome',
#                                                                                 'Education',
#                                                                                 'EnvironmentSatisfaction',
#                                                                                 'HourlyRate',
#                                                                                 'JobInvolvement',
# ...

# %%
print(random_search.best_params_)
# Out:
# {'classifier__n_estimators': 100, 'classifier__min_samples_split': 5, 'classifier__min_samples_leaf': 2, 'classifier__max_features': 'sqrt', 'classifier__max_depth': 5, 'classifier__class_weight': 'balanced'}

# %%
print(random_search.best_score_)
# Out:
# 0.5684210526315789

# %%
best_model = random_search.best_estimator_

# %%
y_pred_best = best_model.predict(X_test)

print(classification_report(
    y_test,
    y_pred_best
))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88       247
#            1       0.43      0.62      0.50        47
#
#     accuracy                           0.81       294
#    macro avg       0.67      0.73      0.69       294
# weighted avg       0.84      0.81      0.82       294

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(
    best_model,
    X_test,
    y_test,
    cmap="Blues"
)

plt.title("Confusion Matrix")
plt.savefig(
    "../images/confusion_matrix.png",
    dpi=300,
    bbox_inches="tight"
)
plt.show()

# %%
import joblib

joblib.dump(best_model, "../models/employee_attrition_model.pkl")
# Out:
# ['../models/employee_attrition_model.pkl']

# %%
print(X.columns.tolist())
# Out:
# ['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
